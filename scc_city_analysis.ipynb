# %%
from common_lib import read_proc_contest
from analysis import make_all_figs

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

for city in ["Los Altos", "Mountain View"]:
    for year in [2020, 2022]:
        path = f"{year}/ca/county/santa_clara/general"
        contest_query = f"(jurisdiction == '{city}') & (office == 'Council')"
        df_proc = read_proc_contest(path, title=f"{year} {city} City Council", contest_query=contest_query)
        _ = make_all_figs(df_proc)
# Out:
# read_proc_contest: 0.9s
# read_proc_contest: 0.7s
# read_proc_contest: 0.9s
# read_proc_contest: 0.6s
