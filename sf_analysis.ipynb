# %%
from common_lib import read_full
from analysis import go

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
path = "2020/ca/city/san_francisco/general"
df = read_full(path)
df = df[df["is_vote"] & ~df["is_ambiguous"]]
df = df[~df["ranked"] & (df["vote_for"] > 1)]
# Out:
# read_full: 6.9s

# %%
go(df)
# Out:
#                                      votes  result
# candidate_id name
# 10           JENNY LAM              195047  winner
# 12           MARK SANCHEZ           194581  winner
# 11           KEVINE BOGGESS         175095  winner
# 13           MATT ALEXANDER         149048  winner
# 7            ALIDA FISHER           143515
# 14           MICHELLE PARKER        117263
# 15           NICK ROTHMAN            56887
# 9            GENEVIEVE LAWRENCE      56755
# 8            ANDREW DOUGLAS ALSTON   33052
# 16           PAUL KANGAS             22662
# 128          Write-in                 1819
#                                 votes  result
# candidate_id name
# 51           SHANELL WILLIAMS  195126  winner
# 52           TOM TEMPRANO      186364  winner
# 44           ALIYA CHISTI      126751  winner
# 43           ALAN WONG         123249  winner
# 45           ANITA MARTINEZ    117515
# 50           MARIE HURABIELL    86627
# 48           HAN ZOU            74858
# 53           VICTOR OLIVIERI    72705
# 49           JEANETTE QUICK     57859
# 47           GERAMYE TEETER     25538
# 46           DOMINIC ASHE       18530
# 123          Write-in            1639
