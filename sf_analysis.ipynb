# %%
from common_lib import read_proc_contest
from analysis import make_all_figs

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

mark_query = "is_vote & ~is_ambiguous"

data = [
    {
        "path": "2020/ca/city/san_francisco/general", 
        "title": "2020 SF School Board", 
        "contest_query": "contest_id == 8",
        "mark_query": mark_query
    },
    {
        "path": "2020/ca/city/san_francisco/general", 
        "title": "2020 SF Community College District", 
        "contest_query": "contest_id == 9",
        "mark_query": mark_query
    },
]

for kwargs in data:
    df = read_proc_contest(**kwargs)
    figs = make_all_figs(df)
# Out:
# read_proc_contest: 2.6s
# read_proc_contest: 2.6s
