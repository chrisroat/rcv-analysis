# %%
# %load_ext autoreload
# %autoreload 2

from common_lib import read_proc
from notebook_utils import make_all_plots

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
path = "2020/ca/county/santa_clara/general"
data_proc = read_proc(path)
# Out:
# read_proc: 3.3s

# %%
df_contest = data_proc["contest"]
df_office = data_proc["office"]
df_mark = data_proc["mark"]
df_candidate = data_proc["candidate"]

office_sel = ((df_office["jurisdiction"] == "Los Altos") & (df_office["office"] == "Council"))
df = df_office[office_sel].join(df_contest).join(df_mark).join(df_candidate)

# %%
df.attrs["contest"] = "2020 Los Altos City Council"
make_all_plots(df)
