# %%
# %load_ext autoreload
# %autoreload 2

from common_lib import read_full
from analysis import go

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
path = "2020/ca/county/santa_clara/general"
df = read_full(path)
df = df[(df["level"] == "City")&(df["jurisdiction"] == "Los Altos")&(df["office"] == "Council Member")]
# Out:
# read_full: 9.4s

# %%
go(df)
