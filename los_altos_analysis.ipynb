# %%
from common_lib import read_proc_contest
from analysis import make_all_figs

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

path = "2020/ca/county/santa_clara/general"
contest_query = "(jurisdiction == 'Los Altos') & (office == 'Council')"
df_proc = read_proc_contest(path, title="2020 Los Altos City Council", contest_query=contest_query)
_ = make_all_figs(df_proc)
# Out:
# read_proc_contest: 2.9s
